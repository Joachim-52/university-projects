# %% [markdown]
# # Example 1

# %% [markdown]
# ## Type casting

# %%
number = int("123")
pi = float("3.14159")
int_pi = int(pi)
ready = bool(12)
pi_str = str(pi)

print(f"{number} of type {type(number)}")
print(f"{pi} of type {type(pi)}")
print(f"{int_pi} of type {type(int_pi)}")
print(f"{ready} of type {type(ready)}")
print(f"{pi_str} of type {type(pi_str)}")
# Out:
# 123 of type <class 'int'>
# 3.14159 of type <class 'float'>
# 3 of type <class 'int'>
# True of type <class 'bool'>
# 3.14159 of type <class 'str'>

# %% [markdown]
# ## Input

# %%
n_beers = int(input("Waiter: How many beers do you want?"))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[14], line 1
# ----> 1 n_beers = int(input("Waiter: How many beers do you want?"))
#
# ValueError: invalid literal for int() with base 10: ''

# %%
print(f"{n_beers} of type {type(n_beers)}") # using print you cannot distinguish betweeen Integer and String
# Out:
# 5 of type <class 'int'>

# %%
# What is the output?
if n_beers > 3:
    print("Waiter: Sorry, we only have three beers left.")
else:
    print(f"Waiter: OK, I'll bring you {n_beers} beer.")
# Out:
# Waiter: Sorry, we only have three beers left.

# %%
n_beers = int(n_beers)
print(f"{n_beers} of type {type(n_beers)}")
# Out:
# 3 of type <class 'int'>

# %%
if n_beers > 3:
    print("Waiter: Sorry, we only have three beers left.")
else:
    print(f"Waiter: OK, I'll bring you {n_beers} beer.")
# Out:
# Waiter: Sorry, we only have three beers left.

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # Example 2

# %% [markdown]
# ## Lists revisited

# %%
drinks = ["beer", "schnaps", "cola"]
print(drinks)
drinks.append("pepsico")
print(drinks)
# Out:
# ['beer', 'schnaps', 'cola']
# ['beer', 'schnaps', 'cola', 'pepsico']

# %%
# add elements to the end of the list using append()
drinks.append("water")

# %%
print(drinks)
# Out:
# ['beer', 'schnaps', 'cola', 'pepsico', 'water']

# %%
# remove the first matching element of the list using remove()
drinks.remove("schnaps")

# %%
print(drinks)
# Out:
# ['beer', 'cola', 'pepsico', 'water']

# %%
drinks = ["beer", "schnaps", "cola", "schnaps"]
print(drinks)
# check if it really only removes the first occuring element
drinks.remove("schnaps")
print(drinks)
# Out:
# ['beer', 'schnaps', 'cola', 'schnaps']
# ['beer', 'cola', 'schnaps']

# %%
# remove the last element using pop()
drinks.pop()
print(drinks)
# Out:
# ['beer', 'cola']

# %%
drinks = ["beer", "cola", "schnaps"]
drinks.pop(0) # drops the first element (0-based index)
print(drinks)
# Out:
# ['cola', 'schnaps']

# %%
drinks.pop(1) # drops the second element, what is the output?
print(drinks)
# Out:
# ['cola']

# %%
drinks = ["beer", "cola", "schnaps"]
n_drinks = len(drinks) # get length of the list
print(n_drinks)
# Out:
# 3

# %% [markdown]
# ### pop() returns the removed item

# %%
drinks = ["beer", "cola", "schnaps"]
print(drinks.pop(0))
print(drinks)
# Out:
# beer
# ['cola', 'schnaps']

# %% [markdown]
# ## Tuples

# %%
stages_of_life = ("birth", "lifetime", "death")

# %%
print(stages_of_life[0])
print(stages_of_life[1])
print(stages_of_life[-1]) # negative indexing
print(stages_of_life[-2])
# Out:
# birth
# lifetime
# death
# lifetime

# %%
# iterate over elements in tuple (same as in lists)
for stage in stages_of_life:
    print(stage)
# Out:
# birth
# lifetime
# death

# %%
stages_of_life.pop() # what is the output?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 1
# ----> 1 stages_of_life.pop() # what is the output?
#
# AttributeError: 'tuple' object has no attribute 'pop'

# %%
stages_of_life[-1] = "immortal" # what happens if we want to change last element?
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 stages_of_life[-1] = "immortal" # what happens if we want to change last element?
#
# TypeError: 'tuple' object does not support item assignment

# %%
stages_of_life.append("hell") # what happens if we want to add an element?
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[10], line 1
# ----> 1 stages_of_life.append("hell") # what happens if we want to add an element?
#
# AttributeError: 'tuple' object has no attribute 'append'

# %% [markdown]
# ## Sets

# %%
my_interests = {"gambling", "music", "drinking"}
friends_interests = {"sports", "music", "cooking"}
print(my_interests.intersection(friends_interests))
print(my_interests.union(friends_interests))
# Out:
# {'music'}
# {'drinking', 'gambling', 'cooking', 'music', 'sports'}

# %%
my_interests = ["gambling", "music", "drinking", "gambling"]
my_interests_set = set(my_interests) # cast the list to a set for removing duplicates

print(my_interests)
print(my_interests_set)
# Out:
# ['gambling', 'music', 'drinking', 'gambling']
# {'gambling', 'drinking', 'music'}

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # Example 3

# %% [markdown]
# ## Dictionaries

# %%
friends_age = {"Thomas": 28, "Frank": 27, "Thorsten": 26}
print(friends_age)
# Out:
# {'Thomas': 28, 'Frank': 27, 'Thorsten': 26}

# %%
print(friends_age["Frank"])
# Out:
# 27

# %%
print(friends_age["Anna"])
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[17], line 1
# ----> 1 print(friends_age["Anna"])
#
# KeyError: 'Anna'

# %%
"Anna" in friends_age # Check if a given key is in the dictionary
# Out:
# False

# %%
# iterate over the keys in a dictionary
for key in friends_age.keys():
    print(f"{key} is {friends_age[key]} years old.")
# Out:
# Thomas is 28 years old.
# Frank is 27 years old.
# Thorsten is 26 years old.

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # Example 4

# %%
hello_msg = "Hello World!"

# %%
print(hello_msg[0])
print(hello_msg[-1])
print(hello_msg[0:2])
print(hello_msg[6:11])
print(hello_msg[0:])
print(hello_msg[0::2])
print(hello_msg[::-1])

# %%
# check if a sequence of characters is in a string
"Hello" in hello_msg

# %%
for character in hello_msg:
    print(character)

# %%
print(hello_msg.upper())
print(hello_msg.lower())
print("  Hello World!   ".strip())

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # Example 5

# %% [markdown]
# ## Functions

# %%
def say_hello_function():
    print("Hello from a function")

# %%
say_hello_function()

# %%
def say_hello_to_friend(friends_name):
    print(f"Hello {friends_name}")

# %%
say_hello_to_friend("Peter")

# %%
say_hello_to_friend("Frank")

# %%
def introduce_myself(friends_name, my_name="Tom"):
    print(f"Hello {friends_name}, I'm {my_name}.")

# %%
introduce_myself("Peter")
introduce_myself("Peter", "Niklas") # positional arguments
introduce_myself(friends_name="Peter", my_name="Niklas") # keyword arguments
introduce_myself(my_name="Niklas", friends_name="Peter") # order does not matter with keyword arguments

# %%
introduce_myself("Niklas", "Peter") # What is the output?

# %%
# define function with arbitrary parameters
def greet_all_friends(*friends):
    for friend in friends:
        print(f"Hi {friend}!")
        
greet_all_friends("Peter", "Thomas")

# %% [markdown]
# # Example 6

# %% [markdown]
# ## Return values

# %%
def pythagoras(a, b):
    return a**2 + b**2

# %%
c_squared = pythagoras(2, 5)
print(c_squared)

# %%
def pythagoras_with_input(a, b):
    c_squared = a**2 + b**2
    return (a, b, c_squared)

# %%
result = pythagoras_with_input(5, 5)
print(result)

# %%
def pythagoras_print(a, b):
    print(a**2 + b**2)

# %%
pythagoras_print(2, 5)

# %%
print(f"The result of 2^2 + 5^2 = {pythagoras(2, 5)}")

# %%
print(f"The result of 2^2 + 5^2 = {pythagoras_print(2, 5)}")

# %% [markdown]
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>
# <br>

# %% [markdown]
# # Example 7

# %% [markdown]
# ## Variable scope

# %%
a = 0          # This is a global variable 
if a == 0: 
    b = 1      # This is still a global variable 

def my_function(c): 
    d = 3      # this is a local variable 
    print(f"c={c} d={d}") 

my_function(7) # Call the function, passing 7 as parameter 

print(f"a={a} b={b}") # a and b still exist 
print(c)       # c doesn't exist anymore --> error
print(d)       # d doesn't exist anymore --> error

# %% [markdown]
# ### Watch out where you define variables!

# %%
e = 1          # This is a global variable 
if e == 0: 
    f = 1      # This is also a global variable

print(f"e={e} f={f}") # what is the output?
