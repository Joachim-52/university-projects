# %%
import requests

# %%
response_tu = requests.get("http://www.tugraz.at/index.php")

# %%
print(response_tu.text[:150])

# %%
response_zamg = requests.get("http://www.zamg.ac.at/ogd/tawes1h.csv")
print(response_zamg.text)

# %%
import pandas

weather_data = pandas.read_csv("http://www.zamg.ac.at/ogd/tawes1h.csv", sep=";")

# %%
weather_data

# %%
weather_data.loc[weather_data.Name == "Graz/Flughafen", :]
