# %% [markdown]
# # In-Person Session 6: More Dictionaries

# %% [markdown]
# ## Information
#
# The following tasks are designed to help you practice the contents of the lecture.
# We strongly encourage you to solve these tasks **before** the next in-person session, as you can receive **up to 3 bonus points** if you present your solution(s) there.
#
# ### How to get bonus points
#
# 1. Solve as many of the following tasks as possible.
# 2. Attend the next in-person session.
# 3. Raise your hands and volunteer to present your solution to one task.
# 4. If more than one students volunteer to present a solution to a task, one student will be selected at random.
# 5. The selected student will now present the solution.
#
# You can bring your own laptop to the front to present the solution. If you don't have a laptop please bring a storage device or paper with your solutions.
#
# **Important:** This is **not** an examination, which means you can only earn (bonus) points.
# You cannot lose points or anything like that if you cannot explain your code or make a mistake.
# The goal of these in-person sessions is that you practice the lecture content as early as possible and get rewarded for it.
# Also, by presenting your solutions, you will get immediate feedback on your code/solutions, which should help you learn Python :)
#
# ### Rules & Restrictions
#
# You can only earn **up to 3 bonus points per in-person session**. Even if you present more than two tasks.
#
# There are some additional restrictions on how bonus points can improve your grade in this course:
# First, it is not possible to earn more than the maximum points for the practical part of the course (i.e., 85 P). For example, if a student achieves 84 points plus 5 bonus points, the total score is still 85 points). Second, bonus points are only considered if at least 50 non-bonus points are achieved in the entire course (i.e., bonus points cannot be used to achieve a positive grade).
#
# Your solutions **MUST NOT be hardcoded**. They have to work with any suitable data provided!
#
# Also make sure to be able to explain your implementations in detail!

# %% [markdown]
# ## Dictionaries
#
# ### Farm (3P)
# You have constructed a list `crops_harvest` of some crops you grow on your farm containing a dictionary with the name and harvest quantity of every crop.\
# The goal is now to calculate the total revenue of the crop using another dictionary `crops_value` containing all the values of your crops.
# To do this you should edit `crops_harvest`: In the dictionary of each crop you should add the key "revenue" and it's corresponding value: `revenue = harvest * value`
# The final `crops_harvest` should look like this:
# ```
# [
#     {'name': 'Beet', 'harvest': 80, 'revenue': 16000},
#     {'name': 'Cranberries', 'harvest': 36, 'revenue': 5400},
#     {'name': 'Eggplant', 'harvest': 50, 'revenue': 6000},
#     {'name': 'Grape', 'harvest': 60, 'revenue': 9600}
# ]
# ```
# You should also print out the total revenue of all crops: "The total revenue is 37000 money."

# %%
crops_harvest = [
    {'name': 'Beet', 'harvest': 80},
    {'name': 'Cranberries', 'harvest': 36},
    {'name': 'Eggplant', 'harvest': 50},
    {'name': 'Grape', 'harvest': 60}
]
crops_value = {'Beet': 200, 'Cranberries': 150, 'Eggplant': 120, 'Grape': 160}

# Write your code here:

# %% [markdown]
# ### Motivated friends (3P)
# You are given 2 lists:
# `friends`: A list of your friends' names.\
# `motivation`: A list of integers representing each friend's motivation level, where higher values indicate higher motivation.
#
# Depending on their motivation level, your friends are either part of the study group (motivation > 50) or they want to go out for coffee.
# This should be represented in a dictionary. The final dictionary should look like this:
# ```
# {
#     'studygroup': ['Vanessa', 'Josef', 'Jonas', 'Christoph', 'Michaela'],
#     'coffee': ['Konstantin', 'Lisa', 'Olaf', 'Magdalena', 'Nikolaus', 'Merte', 'Natascha']
# }
# ```

# %%
friends = ["Konstantin", "Lisa", "Olaf", "Vanessa", "Magdalena", "Nikolaus", "Merte", "Natascha", "Josef", "Jonas", "Christoph", "Michaela"]
motivation = [45, 34, 33, 97, 32, 0, 2, 3, 100, 89, 78, 99]

# Write your code here:

# %% [markdown]
# ### And the Oscar goes to … (3P)
#
# Write a function `academy_awards` that takes a dictionary `oscar_winners` as parameter. The dictionary contains each nomination category as the key, and the respective movie (the movie that won that category) as the value.
#
# Find out which movie won the most academy awards and also print how many awards that movie won.\
# Ultimately, return a dictionary with each unique movie as a key and the number of awards won as the respective value.
#
# For the given dictionary `oscar_winners` the function should print:
# ```
# Most awards: Dune (2)
# ```
# and return:
# ```
# {'Dune': 2, 'The Eyes of Tammy Faye': 1, 'No Time to Die': 1}
# ```
# where the keys of the returned dictionary don't necessarily have to be in the same order as shown above.

# %%
oscar_winners = {
    "Best Actress": "The Eyes of Tammy Faye",
    "Best Original Song": "No Time to Die",
    "Best Sound": "Dune",
    "Best Visual Effects": "Dune"
}

# Write your code here:
