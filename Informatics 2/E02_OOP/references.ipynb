# %% [markdown]
# # References: What's the worst that can happen?

# %%
# Create a list
numbers = [1, 2, 3]

# %%
# Assign it to another variable
copy_numbers = numbers

# %%
# Modify the second list
copy_numbers.append(4)

# %%
# Check both lists
print("numbers:", numbers)
print("copy_numbers:", copy_numbers)
